# %%
# Import dependencies
import pandas as pd
# For data base creation
from sqlalchemy import create_engine
from config import db_password
import os
import glob

# %% [markdown]
# ## Initial Clean up of sourced data
# * We want to combine the winners and looser columns into one player column and add an extra column to distinguish wether that specific player won the match or not.
#     * First we need to separate the loosers from the winners and drop their titles so that they are same
#     * Next we need to add a column called 'result' and place values for each player in the form of 1 and 0 to represent wether they won or not.
#     * Now combine them back together.
# * Finally we will create a final df with sampled data from each year for our data base.

# %%
# Define directory path for files to keep from retyping every time
file_dir = 'Data/Resources/Match_Stats/'

# %%
# assign path
path, dirs, files = next(os.walk("Data/Resources/Match_Stats/"))
file_count = len(files)
# create empty list
dataframes_list = []
 
# append datasets to the list
for i in range(file_count):
    temp_df = pd.read_csv("Data/Resources/Match_Stats/"+files[i])
    dataframes_list.append(temp_df)

tennis_stats_df = pd.concat(dataframes_list)
len(tennis_stats_df)
# Out:
# 75136

# %%
tennis_stats_df
# Out:
#      tourney_id                tourney_name surface  draw_size tourney_level  \
# 0     2019-M020                    Brisbane    Hard         32             A
# 1     2019-M020                    Brisbane    Hard         32             A
# 2     2019-M020                    Brisbane    Hard         32             A
# 3     2019-M020                    Brisbane    Hard         32             A
# 4     2019-M020                    Brisbane    Hard         32             A
# ...         ...                         ...     ...        ...           ...
# 2896   2014-605                 Tour Finals    Hard          8             F
# 2897   2014-605                 Tour Finals    Hard          8             F
# 2898  2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4             D
# 2899  2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4             D
# 2900  2014-D015  Davis Cup WG F: FRA vs SUI    Clay          4             D
#
#       tourney_date  match_num  winner_id winner_seed winner_entry  ...  \
# 0         20181231        300     105453         2.0          NaN  ...
# 1         20181231        299     106421         4.0          NaN  ...
# 2         20181231        298     105453         2.0          NaN  ...
# 3         20181231        297     104542         NaN           PR  ...
# 4         20181231        296     106421         4.0          NaN  ...
# ...            ...        ...        ...         ...          ...  ...
# 2896      20141109        514     104925         1.0          NaN  ...
# 2897      20141109        515     104925         1.0          NaN  ...
# 2898      20141121          1     104527         NaN          NaN  ...
# 2899      20141121          2     104792         NaN          NaN  ...
# 2900      20141121          4     103819         NaN          NaN  ...
#
#      l_1stIn l_1stWon  l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank  \
# 0       54.0     34.0      20.0    14.0       10.0       15.0         9.0
# 1       52.0     36.0       7.0    10.0       10.0       13.0        16.0
# 2       27.0     15.0       6.0     8.0        1.0        5.0         9.0
# 3       60.0     38.0       9.0    11.0        4.0        6.0       239.0
# 4       56.0     46.0      19.0    15.0        2.0        4.0        16.0
# ...      ...      ...       ...     ...        ...        ...         ...
# 2896    38.0     29.0       5.0    11.0        3.0        9.0         1.0
# 2897     NaN      NaN       NaN     NaN        NaN        NaN         1.0
# 2898     NaN      NaN       NaN     NaN        NaN        NaN         4.0
# 2899     NaN      NaN       NaN     NaN        NaN        NaN        19.0
# 2900     NaN      NaN       NaN     NaN        NaN        NaN         2.0
#
#      winner_rank_points loser_rank loser_rank_points
# 0                3590.0       16.0            1977.0
# 1                1977.0      239.0             200.0
# 2                3590.0       40.0            1050.0
# 3                 200.0       31.0            1298.0
# 4                1977.0       18.0            1855.0
# ...                 ...        ...               ...
# 2896            10010.0        5.0            4625.0
# 2897            10010.0        2.0            8700.0
# 2898             5295.0       12.0            2740.0
# 2899             1825.0        2.0            9700.0
# 2900             9700.0       26.0            1350.0
#
# [75136 rows x 49 columns]

# %%
# Display list of column names sorted
sorted(tennis_stats_df.columns.tolist())
# Out:
# ['best_of',
#  'draw_size',
#  'l_1stIn',
#  'l_1stWon',
#  'l_2ndWon',
#  'l_SvGms',
#  'l_ace',
#  'l_bpFaced',
#  'l_bpSaved',
#  'l_df',
#  'l_svpt',
#  'loser_age',
#  'loser_entry',
#  'loser_hand',
#  'loser_ht',
#  'loser_id',
#  'loser_ioc',
#  'loser_name',
#  'loser_rank',
#  'loser_rank_points',
#  'loser_seed',
#  'match_num',
#  'minutes',
#  'round',
#  'score',
#  'surface',
#  'tourney_date',
#  'tourney_id',
#  'tourney_level',
#  'tourney_name',
#  'w_1stIn',
#  'w_1stWon',
#  'w_2ndWon',
#  'w_SvGms',
#  'w_ace',
#  'w_bpFaced',
#  'w_bpSaved',
#  'w_df',
#  'w_svpt',
#  'winner_age',
#  'winner_entry',
#  'winner_hand',
#  'winner_ht',
#  'winner_id',
#  'winner_ioc',
#  'winner_name',
#  'winner_rank',
#  'winner_rank_points',
#  'winner_seed']

# %%
# Remove unnecessary columns
tennis_stats_df.drop(columns=['best_of',
                             'draw_size',
                             'loser_entry',
                             'loser_ht',
                             'loser_ioc',
                             'loser_name',
                             'loser_rank_points',
                             'loser_seed',
                             'match_num',
                             'minutes',
                             'tourney_level',
                             'winner_entry',
                              'winner_ht',
                              'winner_ioc',
                              'winner_name',
                              'winner_rank_points',
                              'winner_seed',
                              'tourney_id'
], inplace=True)
tennis_stats_df.head()
# Out:
#   tourney_name surface  tourney_date  winner_id winner_hand  winner_age  \
# 0     Brisbane    Hard      20181231     105453           R        29.0
# 1     Brisbane    Hard      20181231     106421           R        22.8
# 2     Brisbane    Hard      20181231     105453           R        29.0
# 3     Brisbane    Hard      20181231     104542           R        33.7
# 4     Brisbane    Hard      20181231     106421           R        22.8
#
#    loser_id loser_hand  loser_age           score  ... l_df  l_svpt  l_1stIn  \
# 0    106421          R       22.8     6-4 3-6 6-2  ...  6.0   100.0     54.0
# 1    104542          R       33.7      7-6(6) 6-2  ...  2.0    77.0     52.0
# 2    104871          R       31.8         6-2 6-2  ...  3.0    46.0     27.0
# 3    200282          R       19.8      6-4 7-6(2)  ...  2.0    81.0     60.0
# 4    105683          R       28.0  6-7(2) 6-3 6-4  ...  5.0    94.0     56.0
#
#    l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  winner_rank  loser_rank
# 0      34.0      20.0     14.0       10.0       15.0          9.0        16.0
# 1      36.0       7.0     10.0       10.0       13.0         16.0       239.0
# 2      15.0       6.0      8.0        1.0        5.0          9.0        40.0
# 3      38.0       9.0     11.0        4.0        6.0        239.0        31.0
# 4      46.0      19.0     15.0        2.0        4.0         16.0        18.0
#
# [5 rows x 31 columns]

# %%
# Make a dopy of the tennis_stats dataframe
winners_df = tennis_stats_df.copy()

# %%
# Create winners dataframe 
winners_df.drop(columns=['loser_age',
                         'l_1stIn',
                         'l_1stWon', 
                         'l_2ndWon',
                         'l_SvGms',
                         'l_ace',
                         'l_bpFaced',
                         'l_bpSaved',
                         'l_df',
                         'loser_hand',
                         'loser_rank',
                         'l_svpt'], inplace=True)
winners_df.head()
# Out:
#   tourney_name surface  tourney_date  winner_id winner_hand  winner_age  \
# 0     Brisbane    Hard      20181231     105453           R        29.0
# 1     Brisbane    Hard      20181231     106421           R        22.8
# 2     Brisbane    Hard      20181231     105453           R        29.0
# 3     Brisbane    Hard      20181231     104542           R        33.7
# 4     Brisbane    Hard      20181231     106421           R        22.8
#
#    loser_id           score round  w_ace  w_df  w_svpt  w_1stIn  w_1stWon  \
# 0    106421     6-4 3-6 6-2     F    3.0   3.0    77.0     44.0      31.0
# 1    104542      7-6(6) 6-2    SF   10.0   1.0    52.0     33.0      28.0
# 2    104871         6-2 6-2    SF    2.0   2.0    47.0     33.0      26.0
# 3    200282      6-4 7-6(2)    QF   12.0   2.0    68.0     43.0      34.0
# 4    105683  6-7(2) 6-3 6-4    QF   12.0   3.0   105.0     68.0      48.0
#
#    w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced  winner_rank
# 0      17.0     13.0        3.0        6.0          9.0
# 1      14.0     10.0        0.0        1.0         16.0
# 2       9.0      8.0        2.0        2.0          9.0
# 3      15.0     11.0        4.0        5.0        239.0
# 4      25.0     16.0        8.0        8.0         16.0

# %%
# Add winner column to winners_df with a value of 1
winners_df['result'] = 1
winners_df.head()
# Out:
#   tourney_name surface  tourney_date  winner_id winner_hand  winner_age  \
# 0     Brisbane    Hard      20181231     105453           R        29.0
# 1     Brisbane    Hard      20181231     106421           R        22.8
# 2     Brisbane    Hard      20181231     105453           R        29.0
# 3     Brisbane    Hard      20181231     104542           R        33.7
# 4     Brisbane    Hard      20181231     106421           R        22.8
#
#    loser_id           score round  w_ace  w_df  w_svpt  w_1stIn  w_1stWon  \
# 0    106421     6-4 3-6 6-2     F    3.0   3.0    77.0     44.0      31.0
# 1    104542      7-6(6) 6-2    SF   10.0   1.0    52.0     33.0      28.0
# 2    104871         6-2 6-2    SF    2.0   2.0    47.0     33.0      26.0
# 3    200282      6-4 7-6(2)    QF   12.0   2.0    68.0     43.0      34.0
# 4    105683  6-7(2) 6-3 6-4    QF   12.0   3.0   105.0     68.0      48.0
#
#    w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced  winner_rank  result
# 0      17.0     13.0        3.0        6.0          9.0       1
# 1      14.0     10.0        0.0        1.0         16.0       1
# 2       9.0      8.0        2.0        2.0          9.0       1
# 3      15.0     11.0        4.0        5.0        239.0       1
# 4      25.0     16.0        8.0        8.0         16.0       1

# %%
# Rename columns in winners_df
winners_df.rename(columns={"winner_age":"age",
                           "w_ace":"ace",
                           "w_df":"df",
                           "w_svpt":"svpt",
                           "w_1stIn":"1stIn",
                           "w_1stWon":"1stWon",
                           "w_2ndWon":"2ndWon",
                           "w_SvGms":"svGms",
                           "w_bpFaced":"bpFaced",
                           "w_bpSaved":"bpSaved",
                           "loser_id":"opponent_id",
                           "winner_rank":"rank",
                           "winner_hand":"hand",
                           "winner_id":"player_id"}, inplace=True)
winners_df.head()
# Out:
#   tourney_name surface  tourney_date  player_id hand   age  opponent_id  \
# 0     Brisbane    Hard      20181231     105453    R  29.0       106421
# 1     Brisbane    Hard      20181231     106421    R  22.8       104542
# 2     Brisbane    Hard      20181231     105453    R  29.0       104871
# 3     Brisbane    Hard      20181231     104542    R  33.7       200282
# 4     Brisbane    Hard      20181231     106421    R  22.8       105683
#
#             score round   ace   df   svpt  1stIn  1stWon  2ndWon  svGms  \
# 0     6-4 3-6 6-2     F   3.0  3.0   77.0   44.0    31.0    17.0   13.0
# 1      7-6(6) 6-2    SF  10.0  1.0   52.0   33.0    28.0    14.0   10.0
# 2         6-2 6-2    SF   2.0  2.0   47.0   33.0    26.0     9.0    8.0
# 3      6-4 7-6(2)    QF  12.0  2.0   68.0   43.0    34.0    15.0   11.0
# 4  6-7(2) 6-3 6-4    QF  12.0  3.0  105.0   68.0    48.0    25.0   16.0
#
#    bpSaved  bpFaced   rank  result
# 0      3.0      6.0    9.0       1
# 1      0.0      1.0   16.0       1
# 2      2.0      2.0    9.0       1
# 3      4.0      5.0  239.0       1
# 4      8.0      8.0   16.0       1

# %%
# Make a dopy of the tennis_stats dataframe
losers_df = tennis_stats_df.copy()

# %%
# Create losers dataframe
losers_df.drop(columns=['winner_age',
                         'w_1stIn',
                         'w_1stWon', 
                         'w_2ndWon',
                         'w_SvGms',
                         'w_ace',
                         'w_bpFaced',
                         'w_bpSaved',
                         'w_df',
                         'winner_hand',
                         'winner_rank',
                         'w_svpt'], inplace=True)
losers_df.head()
# Out:
#   tourney_name surface  tourney_date  winner_id  loser_id loser_hand  \
# 0     Brisbane    Hard      20181231     105453    106421          R
# 1     Brisbane    Hard      20181231     106421    104542          R
# 2     Brisbane    Hard      20181231     105453    104871          R
# 3     Brisbane    Hard      20181231     104542    200282          R
# 4     Brisbane    Hard      20181231     106421    105683          R
#
#    loser_age           score round  l_ace  l_df  l_svpt  l_1stIn  l_1stWon  \
# 0       22.8     6-4 3-6 6-2     F    8.0   6.0   100.0     54.0      34.0
# 1       33.7      7-6(6) 6-2    SF   17.0   2.0    77.0     52.0      36.0
# 2       31.8         6-2 6-2    SF   10.0   3.0    46.0     27.0      15.0
# 3       19.8      6-4 7-6(2)    QF    1.0   2.0    81.0     60.0      38.0
# 4       28.0  6-7(2) 6-3 6-4    QF   29.0   5.0    94.0     56.0      46.0
#
#    l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  loser_rank
# 0      20.0     14.0       10.0       15.0        16.0
# 1       7.0     10.0       10.0       13.0       239.0
# 2       6.0      8.0        1.0        5.0        40.0
# 3       9.0     11.0        4.0        6.0        31.0
# 4      19.0     15.0        2.0        4.0        18.0

# %%
# Add loser column to winners_df with a value of 0
losers_df['result'] = 0
losers_df.head()
# Out:
#   tourney_name surface  tourney_date  winner_id  loser_id loser_hand  \
# 0     Brisbane    Hard      20181231     105453    106421          R
# 1     Brisbane    Hard      20181231     106421    104542          R
# 2     Brisbane    Hard      20181231     105453    104871          R
# 3     Brisbane    Hard      20181231     104542    200282          R
# 4     Brisbane    Hard      20181231     106421    105683          R
#
#    loser_age           score round  l_ace  l_df  l_svpt  l_1stIn  l_1stWon  \
# 0       22.8     6-4 3-6 6-2     F    8.0   6.0   100.0     54.0      34.0
# 1       33.7      7-6(6) 6-2    SF   17.0   2.0    77.0     52.0      36.0
# 2       31.8         6-2 6-2    SF   10.0   3.0    46.0     27.0      15.0
# 3       19.8      6-4 7-6(2)    QF    1.0   2.0    81.0     60.0      38.0
# 4       28.0  6-7(2) 6-3 6-4    QF   29.0   5.0    94.0     56.0      46.0
#
#    l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  loser_rank  result
# 0      20.0     14.0       10.0       15.0        16.0       0
# 1       7.0     10.0       10.0       13.0       239.0       0
# 2       6.0      8.0        1.0        5.0        40.0       0
# 3       9.0     11.0        4.0        6.0        31.0       0
# 4      19.0     15.0        2.0        4.0        18.0       0

# %%
# Rename columns in losers_df
losers_df.rename(columns={"loser_age":"age",
                           "l_ace":"ace",
                           "l_df":"df",
                           "l_svpt":"svpt",
                           "l_1stIn":"1stIn",
                           "l_1stWon":"1stWon",
                           "l_2ndWon":"2ndWon",
                           "l_SvGms":"svGms",
                           "l_bpFaced":"bpFaced",
                           "l_bpSaved":"bpSaved",
                           "loser_hand":"hand",
                           "winner_id":"opponent_id",
                           "loser_rank":"rank",
                           "loser_id":"player_id"}, inplace=True)
losers_df.head()
# Out:
#   tourney_name surface  tourney_date  opponent_id  player_id hand   age  \
# 0     Brisbane    Hard      20181231       105453     106421    R  22.8
# 1     Brisbane    Hard      20181231       106421     104542    R  33.7
# 2     Brisbane    Hard      20181231       105453     104871    R  31.8
# 3     Brisbane    Hard      20181231       104542     200282    R  19.8
# 4     Brisbane    Hard      20181231       106421     105683    R  28.0
#
#             score round   ace   df   svpt  1stIn  1stWon  2ndWon  svGms  \
# 0     6-4 3-6 6-2     F   8.0  6.0  100.0   54.0    34.0    20.0   14.0
# 1      7-6(6) 6-2    SF  17.0  2.0   77.0   52.0    36.0     7.0   10.0
# 2         6-2 6-2    SF  10.0  3.0   46.0   27.0    15.0     6.0    8.0
# 3      6-4 7-6(2)    QF   1.0  2.0   81.0   60.0    38.0     9.0   11.0
# 4  6-7(2) 6-3 6-4    QF  29.0  5.0   94.0   56.0    46.0    19.0   15.0
#
#    bpSaved  bpFaced   rank  result
# 0     10.0     15.0   16.0       0
# 1     10.0     13.0  239.0       0
# 2      1.0      5.0   40.0       0
# 3      4.0      6.0   31.0       0
# 4      2.0      4.0   18.0       0

# %%
# Concatenate two (winners and losers) dataframes together
match_stats_df = pd.concat([winners_df, losers_df])
# droping all the NaN in our data
match_stats_df = match_stats_df.dropna()
# Reseting the index
match_stats_df = match_stats_df.reset_index(drop=True)
match_stats_df
# Out:
#        tourney_name surface  tourney_date  player_id hand   age  opponent_id  \
# 0          Brisbane    Hard      20181231     105453    R  29.0       106421
# 1          Brisbane    Hard      20181231     106421    R  22.8       104542
# 2          Brisbane    Hard      20181231     105453    R  29.0       104871
# 3          Brisbane    Hard      20181231     104542    R  33.7       200282
# 4          Brisbane    Hard      20181231     106421    R  22.8       105683
# ...             ...     ...           ...        ...  ...   ...          ...
# 135829  Tour Finals    Hard      20141109     103970    R  32.6       105453
# 135830  Tour Finals    Hard      20141109     105683    R  23.8       103819
# 135831  Tour Finals    Hard      20141109     105683    R  23.8       104918
# 135832  Tour Finals    Hard      20141109     104527    R  29.6       103819
# 135833  Tour Finals    Hard      20141109     105453    R  24.8       104925
#
#                  score round   ace   df   svpt  1stIn  1stWon  2ndWon  svGms  \
# 0          6-4 3-6 6-2     F   3.0  3.0   77.0   44.0    31.0    17.0   13.0
# 1           7-6(6) 6-2    SF  10.0  1.0   52.0   33.0    28.0    14.0   10.0
# 2              6-2 6-2    SF   2.0  2.0   47.0   33.0    26.0     9.0    8.0
# 3           6-4 7-6(2)    QF  12.0  2.0   68.0   43.0    34.0    15.0   11.0
# 4       6-7(2) 6-3 6-4    QF  12.0  3.0  105.0   68.0    48.0    25.0   16.0
# ...                ...   ...   ...  ...    ...    ...     ...     ...    ...
# 135829     4-6 6-4 6-1    RR   2.0  3.0   88.0   48.0    30.0    20.0   14.0
# 135830      6-1 7-6(0)    RR  10.0  2.0   60.0   28.0    22.0    15.0    9.0
# 135831         6-3 7-5    RR   4.0  2.0   62.0   33.0    23.0    14.0   10.0
# 135832  4-6 7-5 7-6(6)    SF  10.0  4.0  123.0   47.0    38.0    36.0   17.0
# 135833     6-1 3-6 6-0    SF   3.0  6.0   67.0   38.0    29.0     5.0   11.0
#
#         bpSaved  bpFaced   rank  result
# 0           3.0      6.0    9.0       1
# 1           0.0      1.0   16.0       1
# 2           2.0      2.0    9.0       1
# 3           4.0      5.0  239.0       1
# 4           8.0      8.0   16.0       1
# ...         ...      ...    ...     ...
# 135829      4.0      9.0   10.0       0
# 135830      4.0      6.0    8.0       0
# 135831      2.0      5.0    8.0       0
# 135832      6.0      9.0    4.0       0
# 135833      3.0      9.0    5.0       0
#
# [135834 rows x 20 columns]

# %%
# number of recorded matchs in our df
len(match_stats_df)
# Out:
# 135834

# %%
# Creating 3 new columns in our main df to refect the 1st and 2nd serve data as percentages
match_stats_df['1stIn(%)'] = round(100 * (match_stats_df['1stIn'] / match_stats_df['svpt']))
match_stats_df['1stWon(%)'] = round(100 * (match_stats_df['1stWon'] / match_stats_df['1stIn']))
match_stats_df['2ndWon(%)'] = round(100 * (match_stats_df['2ndWon'] / (match_stats_df['svpt'] - (match_stats_df['1stIn'] + match_stats_df['df']))))
match_stats_df = match_stats_df.dropna()
len(match_stats_df)
# Out:
# 135794

# %% [markdown]
# # Creating the Data Base

# %%
 # creating the Tennis Database
db_string = f'postgresql://postgres:{db_password}@127.0.0.1:5432/tennis_data'
engine = create_engine(db_string)
match_stats_df.to_sql(name='match_stats', con=engine, if_exists='replace')

# %% [markdown]
# ## Testing different ML models
# We are creating two different test datasets for two different kinds of ML models:
#    * Logistic Regression
#    * Binary Logistic Regression

# %% [markdown]
# ### Logistic Regression

# %%
# pulling 60000 random matches from the main df (match_stats_df)
ML_data = match_stats_df.sample(n = 100000)
# dropping the unnecessary columns for the ML model
ML_data.drop(columns=['tourney_name',
                      'surface',
                      'tourney_date',
                      'player_id',
                      'score',
                      'round',
                      '1stIn',
                      '1stWon',
                      '2ndWon',
                      'opponent_id'
], inplace=True)
# Reseting the index with the new random data
ML_data = ML_data.reset_index(drop=True)
ML_data
# Out:
#       hand   age   ace    df   svpt  svGms  bpSaved  bpFaced   rank  result  \
# 0        R  30.5   5.0   7.0   88.0   14.0      3.0      8.0   65.0       0
# 1        L  26.2   8.0   1.0   55.0   10.0      0.0      1.0  145.0       1
# 2        R  28.7   2.0   1.0   46.0    8.0      4.0      8.0  132.0       0
# 3        R  20.1   4.0   1.0   82.0   14.0      3.0      6.0   15.0       1
# 4        R  21.0   8.0   4.0   44.0    9.0      0.0      0.0   47.0       1
# ...    ...   ...   ...   ...    ...    ...      ...      ...    ...     ...
# 99995    R  23.6  11.0  14.0  147.0   25.0     12.0     20.0    8.0       0
# 99996    R  26.4   4.0   3.0   85.0   11.0      9.0     13.0   46.0       0
# 99997    R  24.5  11.0   6.0  168.0   25.0      5.0      9.0   17.0       1
# 99998    R  21.9  17.0   3.0   57.0   11.0      0.0      0.0    9.0       1
# 99999    R  23.8   4.0   2.0   54.0    8.0      2.0      5.0   26.0       0
#
#        1stIn(%)  1stWon(%)  2ndWon(%)
# 0          43.0       82.0       42.0
# 1          47.0       85.0       75.0
# 2          57.0       58.0       58.0
# 3          49.0       78.0       51.0
# 4          64.0       89.0      100.0
# ...         ...        ...        ...
# 99995      59.0       68.0       67.0
# 99996      56.0       67.0       41.0
# 99997      59.0       70.0       60.0
# 99998      60.0       97.0       80.0
# 99999      67.0       67.0       38.0
#
# [100000 rows x 13 columns]

# %% [markdown]
# ### Binary Logistic Regression

# %%
# Testing data for binary Logistic Regression
# pulling 100000 random matches from the main df (match_stats_df)
ML_data_BLR = match_stats_df.sample(n = 100000)
# dropping the unnecessary columns for the ML model
ML_data_BLR.drop(columns=['tourney_name',
                      'player_id',
                      'score',
                      '1stIn',
                      '1stWon',
                      '2ndWon',
                      'opponent_id',
                      'tourney_date',
                      'round'
], inplace=True)
# Reseting the index with the new random data
ML_data_BLR = ML_data_BLR.reset_index(drop=True)
ML_data_BLR
# Out:
#       surface hand   age   ace   df   svpt  svGms  bpSaved  bpFaced   rank  \
# 0        Hard    L  28.7   7.0  4.0   80.0   12.0      4.0      6.0   50.0
# 1        Hard    R  31.3   6.0  3.0   53.0    8.0      5.0      9.0   49.0
# 2        Hard    R  22.7   2.0  3.0   54.0    7.0      9.0     13.0   43.0
# 3        Hard    R  26.3  13.0  3.0   66.0   11.0      1.0      2.0   62.0
# 4        Clay    R  20.4   4.0  3.0  129.0   18.0      6.0     15.0  113.0
# ...       ...  ...   ...   ...  ...    ...    ...      ...      ...    ...
# 99995    Clay    R  26.9   9.0  4.0  122.0   15.0     11.0     14.0   22.0
# 99996    Hard    R  23.6   5.0  3.0   75.0   12.0      3.0      6.0   11.0
# 99997    Hard    L  26.4   4.0  5.0   55.0    8.0      7.0     11.0   43.0
# 99998    Clay    R  22.6   7.0  8.0  125.0   17.0     12.0     16.0    2.0
# 99999    Hard    R  36.0   5.0  2.0  106.0   19.0      6.0      9.0  262.0
#
#        result  1stIn(%)  1stWon(%)  2ndWon(%)
# 0           0      57.0       74.0       57.0
# 1           0      53.0       61.0       50.0
# 2           0      46.0       60.0       42.0
# 3           1      56.0       84.0       54.0
# 4           0      54.0       59.0       43.0
# ...       ...       ...        ...        ...
# 99995       1      50.0       75.0       51.0
# 99996       0      57.0       74.0       45.0
# 99997       0      60.0       61.0       41.0
# 99998       1      46.0       63.0       62.0
# 99999       1      62.0       74.0       61.0
#
# [100000 rows x 14 columns]

# %%
# Creating table for training data
ML_data.to_sql(name='random_match_stats', con=engine, if_exists='replace')

# %%
# Creating a table in the tennis database for ML_data_BLR
ML_data_BLR.to_sql(name='random_match_stats_BLR', con=engine, if_exists='replace')
